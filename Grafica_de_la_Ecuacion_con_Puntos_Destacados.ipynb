# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandaCorlix/TOPICOSDEIA/blob/main/Grafica_de_la_Ecuacion_con_Puntos_Destacados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Implementamos la biblioteca DEAP

# %%
# !pip install deap

# %% [markdown]
# Los imports que necesitamos para este codigo y la funcion evaluate o evaluacion
# lo que hace la funcion es que toma de entrada la lista (individual) que va a tener 5 valores numeros,  estos son a, b, c, d y e.
# Un arreglo de puntos que es x_points y con ese se va a calcular el y_expected con la formula que tiene ahi
#
# **Formula:**
# a - x**2 + b*x**2 - (c)*x + (d)*np.cos(e*x)

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from deap import base, creator, tools

def evaluate(individual):
    a, b, c, d, e = individual
    x = x_points
    y_expected = a - x**2 + b*x**2 - c*x + d*np.cos(e*x)
    error = np.sum(np.abs(y_expected - y))
    return error,
    #Utilizar y para hacer el vector y la formula

# %% [markdown]
# Aqui se hace lo que es la parte del  DEAP, el fitnessMin hace minimizar la aptitud, el individual hace una lista y tiene como propiedad fitnessMin,  los toolbox registra las operaciones etc, el tamaño de la poblacion es de 100 individuos y con el best_individual se van a almacenar en lo que son las variables, a, b, c, d y e

# %%
# DEAP
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, -10, 10)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=5)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# Create a population
population_size = 100
population = toolbox.population(n=population_size)

# Best individual
best_individual = tools.selBest(population, k=1)[0]
a, b, c, d, e = best_individual

# %% [markdown]
# En esta parte lo que hacemos es que con nuestra lista se calcula los valores de los mejores individuos con sus parametros en el caso de x_points, en el caso de y_values en esta parte se deberia de utilizar la formula que se menciono adelane  de (a - x**2 + b*x**2 - c*x + d*np.cos(e*x)) pero a la  hora de introducirla me mando muchos errores y ningun acercamiento a la grafica que estabamos buscando. pero lo que hace y_values es que los parametros que tiene da un acercamiento a la grafica.

# %%
# Calculate y values using the best individual's parameters
x_points = np.array([-2.0, -1.95959596, -1.91919192, -1.87878788, -1.83838384,
            -1.7979798, -1.75757576, -1.71717172, -1.67676768, -1.63636364,
            -1.5959596, -1.55555556, -1.51515152, -1.47474747, -1.43434343,
            -1.39393939, -1.35353535, -1.31313131, -1.27272727, -1.23232323,
            -1.19191919, -1.15151515, -1.11111111, -1.07070707, -1.03030303,
            -0.98989899, -0.94949495, -0.90909091, -0.86868687, -0.82828283,
            -0.78787879, -0.74747475, -0.70707071, -0.66666667, -0.62626263,
            -0.58585859, -0.54545455, -0.50505051, -0.46464646, -0.42424242,
            -0.38383838, -0.34343434, -0.3030303, -0.26262626, -0.22222222,
            -0.18181818, -0.14141414, -0.1010101, -0.06060606, -0.02020202,
             0.02020202, 0.06060606, 0.1010101, 0.14141414, 0.18181818,
             0.22222222, 0.26262626, 0.3030303, 0.34343434, 0.38383838,
             0.42424242, 0.46464646, 0.50505051, 0.54545455, 0.58585859,
             0.62626263, 0.66666667, 0.70707071, 0.74747475, 0.78787879,
             0.82828283, 0.86868687, 0.90909091, 0.94949495, 0.98989899,
             1.03030303, 1.07070707, 1.11111111, 1.15151515, 1.19191919,
             1.23232323, 1.27272727, 1.31313131, 1.35353535, 1.39393939,
             1.43434343, 1.47474747, 1.51515152, 1.55555556, 1.5959596,
             1.63636364, 1.67676768, 1.71717172, 1.75757576, 1.7979798,
             1.83838384, 1.87878788, 1.91919192, 1.95959596, 2.0])


y_values = ([-9.47530499, -8.20053076, -7.06007355, -6.07004795, -5.27138796, -4.66909356,
 -4.19457453, -3.84919918, -3.65942874, -3.55181112, -3.51373936, -3.57264491,
 -3.64987936, -3.70235606, -3.740946,   -3.77725596, -3.69827274, -3.61302712,
 -3.41808667, -3.08308666, -2.70158321, -2.22867037, -1.6511668,  -1.03678599,
 -0.38456232,  0.33075079,  1.02477883,  1.73094186,  2.36205994,  2.95806084,
  3.4237866,  3.82636692,  4.13496303,  4.27157043,  4.29493587,  4.17829624,
  3.95409283,  3.56992402,  3.12288977,  2.54601402,  1.91026026,  1.22867569,
  0.5422082,  -0.15349255, -0.811973,   -1.42121758, -1.95555196, -2.40673855,
 -2.74191681, -2.9531929,  -3.02569868, -2.96935198, -2.8077883,  -2.51352989,
 -2.1299076,  -1.63410109, -1.10580826, -0.51745204,  0.10152695,  0.72202862,
  1.30413158,  1.86537205,  2.32219095,  2.72308679,  3.03966672,  3.25492871,
  3.40087177,  3.39878705,  3.35382379,  3.21714617,  3.03930083,  2.80648229,
  2.55612964,  2.37850053,  2.17973998,  2.08049234,  2.03455593,  2.11668995,
  2.36365782,  2.70136088,  3.20906666,  3.88418985,  4.75685859,  5.73009392,
  6.89142106,  8.19980283,  9.64580405, 11.17160365, 12.77006736, 14.48209584,
 16.1949218,  17.94359567, 19.65124253, 21.36240072, 23.01681852, 24.63925159,
 26.20180742, 27.69009341, 29.13518722, 30.54860084])

# %% [markdown]
# #Corrida
# En esta parte se muestra la grafica con x_points y y_values
# y  los mejores individuos

# %%
plt.plot(x_points, y_values, label='y = a-x^2 + bx^2 = cx - d cos(ex)')
plt.title('Grafica de la Ecuacion con Puntos Destacados')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.xlim(-2,2)
plt.ylim(-6,6)
plt.grid(True)
plt.show()
print("Mejores individuos")
print(a, b, c, d, e)
# Out:
# Mejores individuos
# -0.39797538874709915 1.2963613578070259 1.06482872398243 1.8642153442681693 -5.895502447004519
