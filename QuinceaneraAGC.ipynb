# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandaCorlix/TOPICOSDEIA/blob/main/QuinceaneraAGC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install googlemaps
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40711 sha256=b9f71f479f8270b1f608cc0cc27bbb33cb111a642da422654522bc6fb2610848
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# ...

# %%
pip install gmplot
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.7/164.7 kB 1.9 MB/s eta 0:00:00
# ...

# %%
pip install deap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 3.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Primera búsqueda utilizando algoritmo genético compacto

# %%
import math
from random import random as rnd
import random
import numpy as np
import googlemaps
from datetime import datetime
import gmplot
from google.colab import files
from IPython.display import HTML
from deap import base, creator, tools, algorithms

# %%
ciudades = {
    "Madrid": {
        "París": 1054,
        "Berlín": 1884,
        "Londres": 1280,
        "Roma": 1505,
        "Atenas": 2895,
        "Lisboa": 628,
        "Viena": 1652,
        "Ámsterdam": 1738,
        "Bruselas": 1498,
        "Varsovia": 2302,
        "Estocolmo": 2755
    },
    "París": {
        "Madrid": 1054,
        "Berlín": 878,
        "Londres": 342,
        "Roma": 1105,
        "Atenas": 2134,
        "Lisboa": 1556,
        "Viena": 1232,
        "Ámsterdam": 431,
        "Bruselas": 305,
        "Varsovia": 1363,
        "Estocolmo": 1530
    },
    "Berlín": {
        "Madrid": 1884,
        "París": 878,
        "Londres": 935,
        "Roma": 1180,
        "Atenas": 1943,
        "Lisboa": 2296,
        "Viena": 547,
        "Ámsterdam": 662,
        "Bruselas": 789,
        "Varsovia": 504,
        "Estocolmo": 1513
    },
    "Londres": {
        "Madrid": 1280,
        "París": 342,
        "Berlín": 935,
        "Roma": 1443,
        "Atenas": 2590,
        "Lisboa": 1894,
        "Viena": 1408,
        "Ámsterdam": 358,
        "Bruselas": 320,
        "Varsovia": 1326,
        "Estocolmo": 1487
    },
    "Roma": {
        "Madrid": 1505,
        "París": 1105,
        "Berlín": 1180,
        "Londres": 1443,
        "Atenas": 827,
        "Lisboa": 1916,
        "Viena": 809,
        "Ámsterdam": 1381,
        "Bruselas": 1418,
        "Varsovia": 1519,
        "Estocolmo": 1997
    },
    "Atenas": {
        "Madrid": 2895,
        "París": 2134,
        "Berlín": 1943,
        "Londres": 2590,
        "Roma": 827,
        "Lisboa": 3257,
        "Viena": 1766,
        "Ámsterdam": 2546,
        "Bruselas": 2438,
        "Varsovia": 2230,
        "Estocolmo": 3037
    },
    "Lisboa": {
        "Madrid": 628,
        "París": 1556,
        "Berlín": 2296,
        "Londres": 1894,
        "Roma": 1916,
        "Atenas": 3257,
        "Viena": 3025,
        "Ámsterdam": 2095,
        "Bruselas": 1831,
        "Varsovia": 2974,
        "Estocolmo": 3414
    },
    "Viena": {
        "Madrid": 1652,
        "París": 1232,
        "Berlín": 547,
        "Londres": 1408,
        "Roma": 809,
        "Atenas": 1766,
        "Lisboa": 3025,
        "Ámsterdam": 1144,
        "Bruselas": 998,
        "Varsovia": 545,
        "Estocolmo": 1349
    },
    "Ámsterdam": {
        "Madrid": 1738,
        "París": 431,
        "Berlín": 662,
        "Londres": 358,
        "Roma": 1381,
        "Atenas": 2546,
        "Lisboa": 2095,
        "Viena": 1144,
        "Bruselas": 173,
        "Varsovia": 936,
        "Estocolmo": 1378
    },
    "Bruselas": {
        "Madrid": 1498,
        "París": 305,
        "Berlín": 789,
        "Londres": 320,
        "Roma": 1418,
        "Atenas": 2438,
        "Lisboa": 1831,
        "Viena": 998,
        "Ámsterdam": 173,
        "Varsovia": 1284,
        "Estocolmo": 1337
    },
    "Varsovia": {
        "Madrid": 2302,
        "París": 1363,
        "Berlín": 504,
        "Londres": 1326,
        "Roma": 1519,
        "Atenas": 2230,
        "Lisboa": 2974,
        "Viena": 545,
        "Ámsterdam": 936,
        "Bruselas": 1284,
        "Estocolmo": 1258
    },
    "Estocolmo": {
        "Madrid": 2755,
        "París": 1530,
        "Berlín": 1513,
        "Londres": 1487,
        "Roma": 1997,
        "Atenas": 3037,
        "Lisboa": 3414,
        "Viena": 1349,
        "Ámsterdam": 1378,
        "Bruselas": 1337,
        "Varsovia": 1258
    }
}

ciudades_nombre = [
        "Madrid",
        "París",
        "Berlín",
        "Londres",
        "Roma",
        "Atenas",
        "Lisboa",
        "Viena",
        "Ámsterdam",
        "Bruselas",
        "Varsovia",
        "Estocolmo"
]

# %%
ciudades['Madrid']['París']
# Out:
# 1054

# %%
class Individuo:
  def __init__(self,cromosoma) -> None:
    self.cromosoma=cromosoma
    self.fitness = None

# %%
def generate_vector(n_genes):
  return [0.5] * n_genes

def generate_candidate(vector):
  value = ""
  for prob in vector:
    value += "1" if rnd() < prob else "0"

  return Individuo(value)

def update_vector(vector, winner, loser, population_size):
    vector_n = []
    for i in range(len(vector)):
        if winner[i] != loser[i]:
            if winner[i] == '1':
                vector[i] += 1.0 / float(population_size)
            else:
                vector[i] -= 1.0 / float(population_size)

# %%
def bits_disponibles(estaciones_disp):
  if estaciones_disp == 0:
    return 1
  else:
    return int(math.log2(estaciones_disp)) + 1

print(bits_disponibles(8))
# Out:
# 4

# %%
def compete(a,b):
  if a.fitness < b.fitness:
    return a, b
  else:
    return b, a

# %%
def dec_ind(ind: str):
  ciudades_nombre_copy = ciudades_nombre.copy()
  camino = []
  ind2 = ''.join(map(str, ind)) #cadena de bits recibida

  for i in range(8):
    cantidad_bits = bits_disponibles(len(ciudades_nombre_copy))

    bits_seleccionados = ind2[:cantidad_bits]
    ind2 = ind2[cantidad_bits:]
    elemento = int(bits_seleccionados,2)

    if elemento >= len(ciudades_nombre_copy):
      elemento = len(ciudades_nombre_copy) - 1

    ciudad_escogida = ciudades_nombre_copy.pop(elemento)

    camino.append(ciudad_escogida)

  return camino

# %%
def fitness_function(ind):
  ciudades = dec_ind(ind.cromosoma)
  distancia_tot = distancia_total(ciudades)
  return distancia_tot

# %%
def fitness_function2(ind):
  individuo = ''.join(map(str, ind))
  ciudades = dec_ind(individuo)
  distancia_tot = distancia_total(ciudades)
  return distancia_tot,

# %%
def distancia_total(ruta):
  total = 0
  for i in range(1, len(ruta)):
    c1 = ruta[i - 1]
    c2 = ruta[i]

    total += ciudades[c1][c2]
  total += ciudades[ruta[-1]][ruta[0]]
  return total

# %%
def run(generaciones, tamano, poblacion,fitness_function):
  vector = generate_vector(tamano)
  best = None


  for i in range(generaciones):

    a = generate_candidate(vector)
    b = generate_candidate(vector)

    a.fitness = fitness_function(a)
    b.fitness = fitness_function(b)

    winner, loser = compete(a, b)

    if best:
      if winner.fitness < best.fitness:
        best = winner
    else:
      best = winner

    update_vector(vector, winner.cromosoma, loser.cromosoma, poblacion)

    print("generation: %d best value: %s best fitness: %f" % (i + 1, best.cromosoma, float(best.fitness)))

  return best.cromosoma

# %%
def graficar_mapa(individuo,algoritmo):
  gmaps = googlemaps.Client(key='AIzaSyCHv7rElmNmFmXOSAj60HQedBwm1SUGBM4')

  individuo2 = dec_ind(individuo)
  individuo2.append(individuo2[0])
  lugares = individuo2

  coordenadas = [gmaps.geocode(ciudad)[0]['geometry']['location'] for ciudad in lugares]

  gmap = gmplot.GoogleMapPlotter(coordenadas[0]['lat'], coordenadas[0]['lng'], 10)

  ruta_lats, ruta_lngs = zip(*[(coord['lat'], coord['lng']) for coord in coordenadas])
  gmap.plot(ruta_lats, ruta_lngs, 'cornflowerblue', edge_width=8)

  for coord in coordenadas:
      gmap.marker(coord['lat'], coord['lng'], 'red')

  gmap.draw(f"{algoritmo}.html")

  HTML(filename=f"/content/{algoritmo}.html")

# %% [markdown]
# # Segunda búsqueda utilizando algoritmo genético de DEAP

# %%
generaciones = 5000
poblacion = 300
tamano = 31

# %%
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("attr_bool", random.randint, 0, 1)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_bool, tamano)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("evaluate", fitness_function2)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.6)
toolbox.register("select", tools.selTournament, tournsize=3)
pop = toolbox.population(n=100)
# Out:
# /usr/local/lib/python3.10/dist-packages/deap/creator.py:185: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /usr/local/lib/python3.10/dist-packages/deap/creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "

# %% [markdown]
# # Comparación

# %%
individuo=run(generaciones,tamano,poblacion,fitness_function)
print(individuo)
print(dec_ind(individuo))
graficar_mapa(individuo,'compacto')
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# generation: 3 best value: 0001111110101011000011100011011 best fitness: 9749.000000
# generation: 4 best value: 0001111110101011000011100011011 best fitness: 9749.000000
# generation: 5 best value: 0000001111001010110011010011101 best fitness: 12989.000000
# generation: 6 best value: 1100000010100101000000011101111 best fitness: 13601.000000
# generation: 7 best value: 1100000010100101000000011101111 best fitness: 13601.000000
# generation: 8 best value: 1100000010100101000000011101111 best fitness: 13601.000000
# generation: 9 best value: 1100000010100101000000011101111 best fitness: 13601.000000
# generation: 10 best value: 1100000010100101000000011101111 best fitness: 13601.000000
# generation: 11 best value: 1100000010100101000000011101111 best fitness: 13601.000000
# generation: 12 best value: 1100000010100101000000011101111 best fitness: 13601.000000
# ...

# %%
pop, logbook = algorithms.eaSimple(pop, toolbox, cxpb=0.6, mutpb=0.2, ngen=400, verbose=True)
best_individual = tools.selBest(pop,k=1)[0]
print(individuo)
print('Individuo')
print(dec_ind(individuo))
print('ruta')
graficar_mapa(best_individual,'deap')
# Out:
# gen	nevals
# 0  	0
# 1  	70
# 2  	63
# 3  	68
# 4  	67
# 5  	70
# 6  	61
# 7  	70
# 8  	73
# 9  	68
# 10 	70
# 11 	69
# 12 	71
# 13 	67
# 14 	73
# 15 	65
# 16 	58
# 17 	60
# 18 	79
# 19 	65
# 20 	67
# 21 	72
# 22 	68
# 23 	73
# 24 	57
# 25 	70
# 26 	77
# 27 	56
# 28 	69
# 29 	69
# 30 	61
# 31 	71
# 32 	75
# 33 	66
# 34 	76
# 35 	72
# 36 	60
# 37 	71
# 38 	63
# 39 	66
# 40 	63
# 41 	73
# 42 	68
# 43 	58
# 44 	59
# 45 	72
# 46 	83
# 47 	65
# 48 	75
# 49 	72
# 50 	63
# 51 	65
# 52 	72
# 53 	72
# 54 	68
# 55 	75
# 56 	65
# 57 	62
# 58 	66
# 59 	66
# 60 	56
# 61 	64
# 62 	61
# 63 	75
# 64 	57
# 65 	63
# 66 	60
# 67 	70
# 68 	75
# 69 	69
# 70 	70
# 71 	74
# 72 	61
# 73 	75
# 74 	59
# 75 	79
# 76 	67
# 77 	57
# 78 	66
# 79 	77
# 80 	74
# 81 	82
# 82 	62
# 83 	71
# 84 	65
# 85 	58
# 86 	53
# 87 	56
# 88 	64
# 89 	74
# 90 	75
# 91 	63
# 92 	64
# 93 	62
# 94 	78
# 95 	79
# 96 	69
# 97 	74
# 98 	73
# 99 	62
# 100	69
# 101	74
# 102	70
# 103	73
# 104	69
# 105	64
# 106	79
# 107	68
# 108	64
# ...
